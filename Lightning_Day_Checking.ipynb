# %% [markdown]
# <a href="https://colab.research.google.com/github/jsdhami/Lightning-Vs-Air-Quality/blob/main/Lightning_Day_Checking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_05092024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05092024.csv')
df_05102024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05102024.csv')
df_05122024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05122024.csv')
df_05132024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05132024.csv')
df_05142024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05142024.csv')
# df_05152024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05152024.csv', encoding='latin-1')
df_05162024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05162024.csv')
df_05172024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05172024.csv')
df_05182024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05182024.csv')
df_05192024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05192024.csv')
df_05202024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05202024.csv')
df_05212024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-05212024.csv')
df_06022024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06022024.csv')
df_06032024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06032024.csv')
df_06042024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06042024.csv')
df_06052024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06052024.csv')
df_06062024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06062024.csv')
df_06072024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06072024.csv')
df_06082024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06082024.csv')
df_06092024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06092024.csv')
df_06102024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06102024.csv')
df_06112024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06112024.csv')
df_06122024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06122024.csv')
df_06132024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06132024.csv')
df_06142024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06142024.csv')
df_06152024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06152024.csv')
df_06162024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06162024.csv')
df_06172024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06172024.csv')
df_06182024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06182024.csv')
df_06192024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06192024.csv')
df_06202024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06202024.csv')
df_06212024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06212024.csv')
df_06222024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06222024.csv')
df_06232024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06232024.csv')
df_06242024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06242024.csv')
df_06252024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06252024.csv')
df_06262024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06262024.csv')
df_06272024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06272024.csv')
df_06282024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06282024.csv')
df_06292024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06292024.csv')
df_06302024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-06302024.csv')
df_07012024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07012024.csv')
df_07022024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07022024.csv')
df_07032024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07032024.csv')
df_07042024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07042024.csv')
df_07052024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07052024.csv')
df_07062024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07062024.csv')
df_07072024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07072024.csv')
df_07082024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07082024.csv')
df_07092024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07092024.csv')
df_07102024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07102024.csv')
df_07112024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07112024.csv')
df_07122024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07122024.csv')
df_07132024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07132024.csv')
df_07142024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07142024.csv')
df_07152024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07152024.csv')
df_07162024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07162024.csv')
df_07172024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07172024.csv')
df_07182024 = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Vs-Air-Quality/main/data/Lightning/Data%20Source%201-07182024.csv')

# %%
data_frames = [
    df_05092024, df_05102024, df_05122024, df_05132024,
    df_05142024, df_05162024, df_05172024, df_05182024,
    df_05192024, df_05202024, df_05212024, df_06022024,
    df_06032024, df_06042024, df_06052024, df_06062024, df_06072024,
    df_06082024, df_06092024, df_06102024, df_06112024, df_06122024,
    df_06132024, df_06142024, df_06152024, df_06162024, df_06172024,
    df_06182024, df_06192024, df_06202024, df_06212024, df_06222024,
    df_06232024, df_06242024, df_06252024, df_06262024, df_06272024,
    df_06282024, df_06292024, df_06302024, df_07012024, df_07022024,
    df_07032024, df_07042024, df_07052024, df_07062024, df_07072024,
    df_07082024, df_07092024, df_07102024, df_07112024, df_07122024,
    df_07132024, df_07142024, df_07152024, df_07162024, df_07172024,
    df_07182024
]

dates = [
    '05/09/2024', '05/10/2024', '05/12/2024', '05/13/2024',
    '05/14/2024', '05/16/2024', '05/17/2024', '05/18/2024',
    '05/19/2024', '05/20/2024', '05/21/2024', '06/02/2024',
    '06/03/2024', '06/04/2024', '06/05/2024', '06/06/2024', '06/07/2024',
    '06/08/2024', '06/09/2024', '06/10/2024', '06/11/2024', '06/12/2024',
    '06/13/2024', '06/14/2024', '06/15/2024', '06/16/2024', '06/17/2024',
    '06/18/2024', '06/19/2024', '06/20/2024', '06/21/2024', '06/22/2024',
    '06/23/2024', '06/24/2024', '06/25/2024', '06/26/2024', '06/27/2024',
    '06/28/2024', '06/29/2024', '06/30/2024', '07/01/2024', '07/02/2024',
    '07/03/2024', '07/04/2024', '07/05/2024', '07/06/2024', '07/07/2024',
    '07/08/2024', '07/09/2024', '07/10/2024', '07/11/2024', '07/12/2024',
    '07/13/2024', '07/14/2024', '07/15/2024', '07/16/2024', '07/17/2024',
    '07/18/2024'
]

# Example of using the dates list in a loop
for i, df in enumerate(data_frames):
    plt.figure(i)
    df.plot(title=f'Data for {dates[i]}')
    plt.show()
